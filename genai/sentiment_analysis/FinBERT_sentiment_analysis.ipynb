# %% [markdown]
# Get RSS Feed

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 1.8 MB/s eta 0:00:00
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6049 sha256=fd65d1668d201171086750b96aa3beddc860d14b74debc7a56560476fcfe0585
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.11 sgmllib3k-1.0.0

# %%
import feedparser

url = "https://feeds.content.dowjones.io/public/rss/mw_topstories"
feed = feedparser.parse(url)

print(feed)
print(len(feed.entries))
# Out:
# {'bozo': False, 'entries': [{'id': 'WP-MKTW-0003217076', 'guidislink': False, 'title': 'Ford keeps EV losses in check, stock jumps 4%', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://feeds.content.dowjones.io/public/rss/mw_topstories', 'value': 'Ford keeps EV losses in check, stock jumps 4%'}, 'summary': 'Carmaker reports a better-than-expected quarter, and EV losses were around Wall Street expectations.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://feeds.content.dowjones.io/public/rss/mw_topstories', 'value': 'Carmaker reports a better-than-expected quarter, and EV losses were around Wall Street expectations.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.marketwatch.com/story/ford-keeps-ev-losses-in-check-stock-jumps-4-8d77e5bc?mod=mw_rss_topstories'}], 'link': 'https://www.marketwatch.com/story/ford-keeps-ev-losses-in-check-stock-jumps-4-8d77e5bc?mod=mw_rss_topstories', 'published': 'Wed, 24 Apr 2024 20:28:00 GMT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=4, tm_mday=24, tm_hour=20, tm_min=28, tm_sec=0, tm_wday=2, tm_yday=115, tm_isdst=0), 'authors': [{'name': 'Claudia Assis'}], 'author': 'Claudia Assis', 'author_detail': {'name': 'Claudia Assis'}, 'media_content': [{'url': 'https://images.mktw.net/im-424599', 'medium': 'image', 'type': 'image/jpeg'}], 'media_credit': [{'content': 'paul ellis/Agence France-Presse/Getty Images'}], 'credit': 'paul ellis/Agence France-Presse/Getty Images'}, {'id': 'WP-MKTW-0003217255', 'guidislink': False, 'title': 'Chipotle shares rally after earnings beat, helped by new menu items', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://feeds.content.dowjones.io/public/rss/mw_topstories', 'value': 'Chipotle shares rally after earnings beat, helped by new menu items'}, 'summary': 'Shares of Chipotle Mexican Grill Inc. rose after hours on Wednesday after the fast-casual Mexican food chain reported first-quarter results that beat expectations, helped by demand for new menu items.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://feeds.content.dowjones.io/public/rss/mw_topstories', 'value': 'Shares of Chipotle Mexican Grill Inc. rose after hours on Wednesday after the fast-casual Mexican food chain reported first-quarter results that beat expectations, helped by demand for new menu items.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.marketwatch.com/story/chipotle-shares-rally-after-earnings-beat-helped-by-new-menu-items-25cc02ea?mod=mw_rss_topstories'}], 'link': 'https://www.marketwatch.com/story/chipotle-shares-rally-after-earnings-beat-helped-by-new-menu-items-25cc02ea?mod=mw_rss_topstories', 'published': 'Wed, 24 Apr 2024 20:27:00 GMT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=4, tm_mday=24, tm_hour=20, tm_min=27, tm_sec=0, tm_wday=2, tm_yday=115, tm_isdst=0), 'authors': [{'name': 'Bill Peters'}], 'author': 'Bill Peters', 'author_detail': {'name': 'Bill Peters'}, 'media_content': [{'url': 'https://images.mktw.net/im-608855', 'medium': 'image', 'type': 'image/jpeg'}], 'media_credit': [{'content': 'Michael M. Santiago/Getty Images'}], 'credit': 'Michael M. Santiago/Getty Images'}, {'id': 'WP-MKTW-0003216354', 'guidislink': False, 'title': 'Nursing homes: Will new federal rules curb abuse and lead to better care?', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://feeds.content.dowjones.io/public/rss/mw_topstories', 'value': 'Nursing homes: Will new federal rules curb abuse and lead to better care?'}, 'summary': 'The challenge of finding and hiring staff at nursing homes is enormous.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://feeds.content.dowjones.io/public/rss/mw_topstories', 'value': 'The challenge of finding and hiring staff at nursing homes is enormous.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.marketwatch. ...
# 10

# %%
titles = [entry.title for entry in feed.entries]
titles
# Out:
# ['Ford keeps EV losses in check, stock jumps 4%',
#  'Chipotle shares rally after earnings beat, helped by new menu items',
#  'Nursing homes: Will new federal rules curb abuse and lead to better care?',
#  'ServiceNow is riding a wave of AI sales for enterprise customers',
#  'Employees work hard when they have a sense of ownership — so make them owners',
#  'Stock-market pessimism is climbing. Why it’s still not bad enough to imply stocks hit a bottom.',
#  '10-year Treasury yield ends near highest levels of 2024 as Fed’s preferred inflation gauge looms',
#  'Goldman Sachs and Bank of America shareholders reject proposals to separate chair and CEO roles',
#  'Transportation stocks sink, with industry ETF on track for biggest drop since October',
#  'These investments will boost your net worth more than any growth stock']

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="ProsusAI/finbert")
pipe(titles)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'label': 'negative', 'score': 0.4951305091381073},
#  {'label': 'positive', 'score': 0.9326735734939575},
#  {'label': 'neutral', 'score': 0.7718669176101685},
#  {'label': 'positive', 'score': 0.7909886837005615},
#  {'label': 'neutral', 'score': 0.886907160282135},
#  {'label': 'negative', 'score': 0.920995831489563},
#  {'label': 'negative', 'score': 0.747851550579071},
#  {'label': 'neutral', 'score': 0.6192106604576111},
#  {'label': 'negative', 'score': 0.9694806933403015},
#  {'label': 'positive', 'score': 0.9086671471595764}]
